# %%
# hey this is Alex's Branch

# %%
# import block
import os, sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_set = pd.read_csv('./data/IoTProcessed_Data.csv')
data_set
# Out:
#                       date  tempreature  humidity  water_level    N    P    K  \
# 0      2024-02-08 06:10:00           41        63          100  255  255  255
# 1      2024-02-08 06:15:00           41        59          100  255  255  255
# 2      2024-02-08 06:20:00           41        62          100  255  255  255
# 3      2024-02-08 06:05:00           40        60          100  255  255  255
# 4      2024-02-08 06:00:00           39        61          100  255  255  255
# ...                    ...          ...       ...          ...  ...  ...  ...
# 37917  2024-02-02 22:20:00            3        59          100  255  255  255
# 37918  2024-02-02 22:25:00            3        60          100  255  255  255
# 37919  2024-02-02 22:30:00            3        60          100  255  255  255
# 37920  2024-02-02 22:35:00            3        59          100  255  255  255
# 37921  2024-02-02 22:40:00            3        59          100  255  255  255
#
# ...

# %%
# clean up and adjusting 

data_set_clean = data_set.copy()
data_set_clean["date"] = pd.to_datetime(data_set_clean["date"])
data_set_clean = data_set_clean.sort_values(by='date')
# Rename the column temporarily for clarity
data_set_clean = data_set_clean.rename(columns={"tempreature": "temperature"})
data_set_clean
# Out:
#                      date  temperature  humidity  water_level    N    P    K  \
# 4023  2023-11-27 06:26:00           29        79          100  185  190  160
# 4022  2023-11-27 06:31:00           29        78          100  185  190  160
# 5823  2023-11-27 06:36:00           28        77          100  185  190  160
# 5822  2023-11-27 06:41:00           28        75          100  185  190  160
# 5821  2023-11-27 06:46:00           28        74          100  185  190  160
# ...                   ...          ...       ...          ...  ...  ...  ...
# 747   2024-03-30 05:22:00           33         0            0  255  255  255
# 748   2024-03-30 05:23:00           33         0            0  255  255  255
# 749   2024-03-30 05:24:00           33         0            0  255  255  255
# 14349                 NaT           20        45           86  255  255  255
# 14350                 NaT           20        45           67  255  255  255
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Plot Date vs Temperature
plt.figure(figsize=(10, 6))
plt.plot(data_set_clean['date'], data_set_clean['temperature'], label='Temperature', linewidth=2)

# Add labels and title
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Checking to see if this works

# %%
print("hey it's Lena and I'm short")
# Out:
# hey it's Lena and I'm short

# %%
#Lets assume we are interested in the data when the Fan_actuator is on 

on_data =  data_set[data_set['Fan_actuator_ON'] == 1]
on_data
# Out:
#                       date  tempreature  humidity  water_level    N    P    K  \
# 0      2024-02-08 06:10:00           41        63          100  255  255  255
# 1      2024-02-08 06:15:00           41        59          100  255  255  255
# 2      2024-02-08 06:20:00           41        62          100  255  255  255
# 3      2024-02-08 06:05:00           40        60          100  255  255  255
# 4      2024-02-08 06:00:00           39        61          100  255  255  255
# ...                    ...          ...       ...          ...  ...  ...  ...
# 11757  2024-02-29 05:48:00           23         0           76  255  255  255
# 11758  2024-02-29 05:51:00           23       100            9  255  255  255
# 11759  2024-02-29 05:51:00           23         0          100  255  255  255
# 11760  2024-02-29 05:52:00           23        86          100  255  255  255
# 13703  2024-01-21 06:01:00           21         5          100  255  255  255
#
# ...
